# %%
import skimage.io as sio
import numpy as np

# %%
orig_png = sio.imread_collection('../data/im_*')

# %%
len(orig_png)
# Out:
# 242

# %%
orig_png[0].dtype
# Out:
# dtype('uint8')

# %%
white = np.array([255, 255, 255], dtype=np.uint8)

# %%
for ii in range(len(orig_png)):
    new_im = orig_png[ii][:, 500:1500, :] - white
    sio.imsave('../imageStacks/biopsy/im_%06d.png'%ii, new_im)

# %%
new_im.shape
# Out:
# (306, 1000, 3)

# %%
sio.imsave?

# %%
sio.imsave('../imageStacks/biopsy/im_%06d'%ii, new_im)
# Out:
# /Users/arokem/anaconda3/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from int64 to float64
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-13-64090782a1b7> in <module>()
# ----> 1 sio.imsave('../imageStacks/biopsy/im_%06d'%ii, new_im)
#
# /Users/arokem/anaconda3/lib/python3.5/site-packages/skimage/io/_io.py in imsave(fname, arr, plugin, **plugin_args)
#     129         if fname.lower().endswith(('.tiff', '.tif')):
#     130             plugin = 'tifffile'
# --> 131     if is_low_contrast(arr):
#     132         warn('%s is a low contrast image' % fname)
#     133     return call_plugin('imsave', fname, arr, plugin=plugin, **plugin_args)
#
# /Users/arokem/anaconda3/lib/python3.5/site-packages/skimage/exposure/exposure.py in is_low_contrast(image, fraction_threshold, lower_percentile, upper_percentile, method)
#     509     image = np.asanyarray(image)
#     510     if image.ndim == 3 and image.shape[2] in [3, 4]:
# --> 511         image = rgb2gray(image)
#     512
#     513     dlimits = dtype_limits(image)
#
# /Users/arokem/anaconda3/lib/python3.5/site-packages/skimage/color/colorconv.py in rgb2gray(rgb)
#     712         return np.ascontiguousarray(rgb)
#     713
# --> 714     rgb = _prepare_colorarray(rgb[..., :3])
#     715
#     716     gray = 0.2125 * rgb[..., 0]
#
# /Users/arokem/anaconda3/lib/python3.5/site-packages/skimage/color/colorconv.py in _prepare_colorarray(arr)
#     151         raise ValueError(msg)
#     152
# --> 153     return dtype.img_as_float(arr)
#     154
#     155
#
# /Users/arokem/anaconda3/lib/python3.5/site-packages/skimage/util/dtype.py in img_as_float(image, force_copy)
#     299
#     300     """
# --> 301     return convert(image, np.float64, force_copy)
#     302
#     303
#
# /Users/arokem/anaconda3/lib/python3.5/site-packages/skimage/util/dtype.py in convert(image, dtype, force_copy, uniform)
#     239         # use float type that can exactly represent input integers
#     240         image = np.array(image, _dtype(itemsize_in, dtype,
# --> 241                                        np.float32, np.float64))
#     242         if kind_in == 'u':
#     243             image /= imax_in
#
# /Users/arokem/anaconda3/lib/python3.5/site-packages/skimage/util/dtype.py in _dtype(itemsize, *dtypes)
#     112     def _dtype(itemsize, *dtypes):
#     113         # Return first of `dtypes` with itemsize greater than `itemsize`
# --> 114         return next(dt for dt in dtypes if itemsize < np.dtype(dt).itemsize)
#     115
#     116     def _dtype2(kind, bits, itemsize=1):
#
# StopIteration:
